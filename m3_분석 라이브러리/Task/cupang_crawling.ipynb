# %% [markdown]
# # 쿠팡 크롤링

# %%
- 대형 사이트들은 데이터 크롤링을 막아놔서 proxy url을 사용

# %% [markdown]
# web_unlocker1
# - right Data의 서비스 중 하나로, 특히 웹 데이터 수집을 위한 프록시 솔루션입니다. Web Unlocker는 특정 웹사이트에 대한 접근을 차단하거나 제한하는 다양한 방어 메커니즘을 우회하도록 설계되어 있습니다. 다음은 Web Unlocker의 주요 기능과 사용 사례에 대한 설명입니다.
# - https://brdta.com/kimfl 링크로 가입하시면 복잡한 절차를 거치지 않아도 $10 무료 크레딧이 즉시 제공됩니다.

# %%
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings(
    "ignore", category=requests.packages.urllib3.exceptions.InsecureRequestWarning
)

host = ''
user_name = ''
password = ''
proxy_url = f'http://{user_name}:{password}@{host}'
proxies = {"http": proxy_url, "https": proxy_url}
print(proxy_url)

keyword = input('검색할 제품을 입력하세요: ')
# keyword = keyword.replace(' ', '+')

url = f"https://www.coupang.com/np/search?component=&q={keyword}&channel=user"

response = requests.get(url, proxies=proxies, verify=False)
html = response.text
soup = BeautifulSoup(html, 'html.parser')
items = soup.select('.search-product')

for item in items:
    title = item.select_one('.name')
    price = item.select_one('.price-value')
    print(title, price)
# Out:
# http://brd-customer-hl_45d17f45-zone-web_unlocker1:gxw6546j5fee@brd.superproxy.io:22225
# <div class="name">삼성전자 갤럭시 S23 FE 자급제 SM-S711N, 그라파이트, 256GB</div> <strong class="price-value">694,540</strong>
# <div class="name">삼성전자 갤럭시 S23 FE 자급제 SM-S711N, 크림, 256GB</div> <strong class="price-value">688,140</strong>
# <div class="name">삼성전자 갤럭시 A15 자급제, 라이트 블루, 128GB</div> <strong class="price-value">283,990</strong>
# <div class="name">삼성전자 갤럭시 A25 자급제 SM-A256N, 블루 블랙, 128GB</div> <strong class="price-value">382,000</strong>
# <div class="name">삼성 공부폰 파트너사 2024년 최신모델 갤럭시 A15 데이터가 완벽히 차단된 공부폰입니다, 옐로우</div> <strong class="price-value">49,000</strong>
# <div class="name">삼성전자 갤럭시 A15 자급제, 블루 블랙, 128GB</div> <strong class="price-value">280,500</strong>
# <div class="name">삼성전자 갤럭시 S23 FE 자급제 SM-S711N, 민트, 256GB</div> <strong class="price-value">694,540</strong>
# <div class="name">삼성전자 갤럭시 S24 자급제, 오닉스 블랙, 256GB</div> <strong class="price-value">1,042,980</strong>
# <div class="name">갤럭시 z플립4 케이스 뮤즈 링가드 힌지보호 핑거링 가죽 케이스</div> <strong class="price-value">17,900</strong>
# <div class="name">삼성전자 갤럭시 S24 Ultra 자급제, 티타늄 블랙, 256GB</div> <strong class="price-value">1,510,450</strong>
# <div class="name">삼성전자 갤럭시 S24 자급제, 마블 그레이, 256GB</div> <strong class="price-value">1,042,980</strong>
# <div class="name">볼케 시큐어 컴플릿 가드 갤럭시 Z플립3(F711)</div> <strong class="price-value">26,010</strong>
# <div class="name">유심-헬로모바일 알뜰폰 알뜰요금제 유심 사은품 4G/5G요금제 갤럭시S/아이폰15 자급제</div> <strong class="price-value">4,500</strong>
# <div class="name">삼성전자 갤럭시 A25 자급제 SM-A256N, 라이트 블루, 128GB</div> <strong class="price-value">382,420</strong>
# <div class="name">삼성전자 갤럭시 S23 FE 자급제 SM-S711N, 퍼플, 256GB</div> <strong class="price-value">694,540</strong>
# <div class="name">삼성전자 갤럭시 A35 자급제 SM-A356N, 어썸네이비, 128GB</div> <strong class="price-value">469,230</strong>
# <div class="name">메이튼 오토 프로 무선 미러링 카플레이 아이폰 전용, ZC001-CP, 0GB</div> <strong class="price-value">79,000</strong>
# <div class="name">삼성전자 갤럭시 A35 자급제 SM-A356N, 어썸라일락, 128GB</div> <strong class="price-value">469,900</strong>
# <div class="name">폰누리 미라쥬 소가죽 카드 수납 지갑형 다이어리 휴대폰 케이스</div> <strong class="price-value">16,900</strong>
# <div class="name">삼성전자 갤럭시 S24+ 자급제, 오닉스 블랙, 256GB</div> <strong class="price-value">1,223,000</strong>
# <div class="name">스마트워치 Y6 통화가능 고화질 AOD기능 스포츠 워치, 블랙</div> <strong class="price-value">57,290</strong>
# <div class="name">유심-KT M모바일 LTE/5G 요금제 갤럭시/Z플립5/아이폰15 자급제 사용가능</div> <strong class="price-value">4,500</strong>
# <div class="name">삼성전자 갤럭시 A15 자급제, 옐로우, 128GB</div> <strong class="price-value">290,000</strong>
# <div class="name">신지모루 갤럭시워치 밀레니즈 밴드 스트랩, 실버</div> <strong class="price-value">9,520</strong>
# <div class="name">
#                                                         Apple 아이폰 13 mini 자급제, 128GB, 미드나이트
#                                                     </div> <strong class="price-value">790,000</strong>
# <div class="name">
#                                                         쵸미앤세븐 샤인큐빅 갤럭시 워치 액티브1/2 메탈밴드 40/44 mm, 실버, 1개
#                                                     </div> <strong class="price-value">23,320</strong>
# <div class="name">
#                                                         삼성전자 갤럭시 휴대폰 S21 SM-G991N, 팬텀 바이올렛, 256GB
#                                                     </div> None
# <div class="name">
#                                                         Apple 아이패드 10.2 2021년 9세대, 실버, 256GB, Wi-Fi
#                                                     </div> <strong class="price-value">670,000</strong>
# <div class="name">
#                                                         아이티스타일 갤럭시워치 마그네틱 스트랩 22mm, 오렌지
#                                                     </div> <strong class="price-value">9,780</strong>
# <div class="name">
#                                                         아이티스타일 갤럭시워치 마그네틱 스트랩 22mm, 로즈골드
#                                                     </div> <strong class="price-value">11,570</strong>
# <div class="name">
#                                                         비쉐르 무지 라운드 갤럭시워치 3 레더 밴드 스트랩 41mm, 핑크, 1개
#                                                     </div> <strong class="price-value">15,620</strong>
# <div class="name">
#                                                         누아트 갤럭시워치 호환 밀레니즈 스트랩 밴드, 실버
#                                                     </div> <strong class="price-value">6,690</strong>
# <div class="name">
#                                                         비쉐르 갤럭시 워치 3 골드 버클 라운드 실리콘 밴드 스트랩 41mm, 바이올렛, 1개
#                                                     </div> <strong class="price-value">17,200</strong>
# <div class="name">
#                                                         아이엠판다 갤럭시워치 액정보호 풀커버 케이스, 골드
#                                                     </div> <strong class="price-value">6,530</strong>
# <div class="name">
#                                                         디씨네트워크 스마트워치 트윈가죽 스트랩 + 강화유리 보호필름 2p 세트, 브라운(스트랩)
#                                                     </div> <strong class="price-value">12,320</strong>
# <div class="name">
#                                                         스카이 웰 갤럭시워치 호환 스테인리스 메탈 쥬빌레 밴드 스트랩 20mm, 로즈골드
#                                                     </div> <strong class="price-value">10,140</strong>
# <div class="name">
#                                                         빅쏘 레빅스킨 초슬림 하드 갤럭시워치 케이스, 투명
#                                                     </div> <strong class="price-value">8,220</strong>
# <div class="name">
#                                                         누아트 변색없는 갤럭시워치5프로 커버 하드케이스 + 프리미엄 9H 고강도 풀커버 강화유리 3개입, 로즈골드(케이스)
#                                                     </div> <strong class="price-value">7,500</strong>
# <div class="name">
#                                                         갤럭시 워치 실리콘 스트랩 밴드 스트랩 20mm 42mm 호환 가능, 오렌지레드
#                                                     </div> <strong class="price-value">9,470</strong>
# <div class="name">
#                                                         스페이스쉴드 갤럭시 워치 브레이드 솔로 루프 나일론 밴드 20mm S, 화이트레드
#                                                     </div> <strong class="price-value">9,400</strong>
# <div class="name">
#                                                         스페이스쉴드 갤럭시 워치 브레이드 솔로 루프 나일론 밴드 20mm L, 화이트레드
#                                                     </div> <strong class="price-value">11,300</strong>
# <div class="name">삼성전자 갤럭시 A35 자급제 SM-A356N, 어썸아이스블루, 128GB</div> <strong class="price-value">469,230</strong>
# <div class="name">삼성전자 갤럭시 A25 자급제 SM-A256N, 옐로우, 128GB</div> <strong class="price-value">382,420</strong>
# <div class="name">삼성전자 갤럭시 S24 Ultra 자급제, 티타늄 그레이, 256GB</div> <strong class="price-value">1,544,500</strong>
# <div class="name">삼성전자 갤럭시 Z 플립5 5G 자급제, 크림, 512GB</div> <strong class="price-value">1,216,170</strong>
# <div class="name">삼성전자 갤럭시 S24+ 자급제, 마블 그레이, 256GB</div> <strong class="price-value">1,227,030</strong>
# <div class="name">삼성전자 갤럭시 A23 공기계 128GB, 블랙</div> <strong class="price-value">133,000</strong>
# <div class="name">삼성전자 갤럭시 S24 자급제, 오닉스 블랙, 512GB</div> <strong class="price-value">1,155,500</strong>
# <div class="name">삼성전자 갤럭시 S24 Ultra 자급제, 티타늄 블랙, 512GB</div> <strong class="price-value">1,694,090</strong>
# <div class="name">삼성전자 갤럭시 Z 플립4 5G 자급제 SM-F721N, purple 퍼플, 256GB</div> <strong class="price-value">438,000</strong>
# <div class="name">삼성전자 갤럭시 S24+ 자급제, 오닉스 블랙, 512GB</div> <strong class="price-value">1,359,000</strong>
# <div class="name">삼성전자 갤럭시 S24 Ultra 자급제, 티타늄 그레이, 512GB</div> <strong class="price-value">1,659,900</strong>
# <div class="name">삼성전자 갤럭시 Z 플립5 5G 자급제, 그라파이트, 256GB</div> <strong class="price-value">1,175,340</strong>
