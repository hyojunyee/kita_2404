# %% [markdown]
# <a href="https://colab.research.google.com/github/hyojunyee/kita_2404/blob/main/m3_%EB%B6%84%EC%84%9D%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC/Task/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_0528.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Q. df1으로 데이터프레임을 생성한 후 set_index를 사용하여 ID를 인덱스 설정한 데이터프레임을 출력하세요.

# %%
df1 = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32]
})
df1
# Out:
#     ID     Name  Age
# 0  101    Alice   24
# 1  102      Bob   27
# 2  103  Charlie   22
# 3  104    David   32

# %%
df1.set_index('ID', inplace=True)
df1
# Out:
#         Name  Age
# ID
# 101    Alice   24
# 102      Bob   27
# 103  Charlie   22
# 104    David   32

# %% [markdown]
# Q. df2에 대해서 다음을 수행하세요.
# - set_index를 사용하여 인덱스를 설정.
# - reset_index를 사용하여 인덱스를 리셋.

# %%
df2 = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32]
})
df2
# Out:
#     ID     Name  Age
# 0  101    Alice   24
# 1  102      Bob   27
# 2  103  Charlie   22
# 3  104    David   32

# %%
# 인덱스를 설정
df2_indexed = df2.set_index('ID')
df2_indexed
# Out:
#         Name  Age
# ID
# 101    Alice   24
# 102      Bob   27
# 103  Charlie   22
# 104    David   32

# %%
# 인덱스를 리셋
df2_reseted = df2_indexed.reset_index()
df2_reseted
# Out:
#     ID     Name  Age
# 0  101    Alice   24
# 1  102      Bob   27
# 2  103  Charlie   22
# 3  104    David   32

# %% [markdown]
# Q. df3에 대해서 reindex를 사용하여 인덱스를 변경하여 출력하세요.

# %%
df3 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32]
}, index=[101, 102, 103, 104])
df3
# Out:
#         Name  Age
# 101    Alice   24
# 102      Bob   27
# 103  Charlie   22
# 104    David   32

# %%
new_index = [101, 102, 201, 202]
df3_reindexed = df3.reindex(new_index)
# df3_reindexed = df3.reindex(new_index, fill_value=0)      # 0으로 채움
df3_reindexed
# Out:
#       Name   Age
# 101  Alice  24.0
# 102    Bob  27.0
# 201    NaN   NaN
# 202    NaN   NaN

# %% [markdown]
# Q. df4에 대해서 reindex를 사용하여 인덱스를 변경하고 결측치를 0으로 채운 데이터프레임을 출력하세요.

# %%
df4 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [24, 27, 22]
}, index=[0, 1, 2])

print("기존 인덱스:\n", df4)
# Out:
# 기존 인덱스:
#        Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22

# %%
df4_reindexed = df4.reindex(np.arange(5), fill_value=0)
df4_reindexed
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3        0    0
# 4        0    0

# %%
new_index = [0, 1, 2, 3, 4]
df4_reindexed = df4.reindex(new_index, fill_value=0)
df4_reindexed
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3        0    0
# 4        0    0

# %% [markdown]
# Q. df5에서 reindex를 사용하여 특정 날짜 범위로 인덱스를 재설정하여 출력하세요.

# %%
dates = pd.date_range('2024-01-01', periods=4, freq='D')
df5 = pd.DataFrame({
    'Value': [10, 20, 30, 40]
}, index=dates)
df5
# Out:
#             Value
# 2024-01-01     10
# 2024-01-02     20
# 2024-01-03     30
# 2024-01-04     40

# %%
new_dates = pd.date_range('2024-01-01', periods=6, freq='D')
df5_reindexed = df5.reindex(new_dates, fill_value=10)
df5_reindexed
# Out:
#             Value
# 2024-01-01     10
# 2024-01-02     20
# 2024-01-03     30
# 2024-01-04     40
# 2024-01-05     10
# 2024-01-06     10

# %% [markdown]
# Q. 데이터프레임 df6를 전치하고, 전치된 데이터프레임을 정리하여 연도별 판매량 데이터를 제품별로 나열하여 출력하세요.

# %%
data = {
    'Year': ['2020', '2021', '2022'],
    'Product_A': [500, 600, 700],
    'Product_B': [400, 500, 600],
    'Product_C': [300, 400, 500]
}
df6 = pd.DataFrame(data)
df6
# Out:
#    Year  Product_A  Product_B  Product_C
# 0  2020        500        400        300
# 1  2021        600        500        400
# 2  2022        700        600        500

# %%
df6_t = df6.transpose()
df6_t.columns = df6_t.iloc[0]
df6_t = df6_t[1:]
df6_t.index.name = 'Product'
df6_t
# Out:
# Year      2020 2021 2022
# Product
# Product_A  500  600  700
# Product_B  400  500  600
# Product_C  300  400  500

# %%
# 데이터를 전치
df_transposed = df6.set_index('Year').T
df_transposed
# Out:
# Year       2020  2021  2022
# Product_A   500   600   700
# Product_B   400   500   600
# Product_C   300   400   500

# %%
# 전치된 데이터프레임 정리
# reset_index를 사용해서 인덱스를 리셋하고, rename을 사용하여 'index' 열을 'Product'로 변경
df_transposed.reset_index(inplace=True)
df_transposed.rename(columns={'index':'product'}, inplace=True)
df_transposed
# Out:
# Year    product  2020  2021  2022
# 0     Product_A   500   600   700
# 1     Product_B   400   500   600
# 2     Product_C   300   400   500
