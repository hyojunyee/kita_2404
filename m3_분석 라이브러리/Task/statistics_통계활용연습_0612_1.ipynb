# %% [markdown]
# <a href="https://colab.research.google.com/github/hyojunyee/kita_2404/blob/main/m3_%EB%B6%84%EC%84%9D%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC/Task/statistics_%ED%86%B5%EA%B3%84%ED%99%9C%EC%9A%A9%EC%97%B0%EC%8A%B5_0612_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Q. 한 학급의 학생 10명의 수학 시험 점수는 다음과 같습니다:
#
# [85, 72, 90, 68, 88, 76, 95, 89, 77, 84].
#
# 학급의 평균 점수와 표준편차를 계산하여 전체 성적 수준과 변동성을 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
T_score = [85, 72, 90, 68, 88, 76, 95, 89, 77, 84]
# mean = np.mean(T_score)
df = pd.DataFrame(T_score)
df.describe()
# Out:
#                0
# count  10.000000
# mean   82.400000
# std     8.733079
# min    68.000000
# 25%    76.250000
# 50%    84.500000
# 75%    88.750000
# max    95.000000

# %%
mean = int(df.mean())
std = int(df.std())
# Out:
# <ipython-input-95-dfd6eedbcb4d>:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   mean = int(df.mean())
# <ipython-input-95-dfd6eedbcb4d>:2: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   std = int(df.std())

# %%
if std > 10:
    print("성적 변동성이 큽니다.")
else:
    print("성적 변동성이 작습니다.")
# Out:
# 성적 변동성이 작습니다.

# %%
# 평균점수가 82점이고 표준편차는 8.7점이다.
# 최대점수(95점)과 최소점수(68점)차이인 27점과 표준편차(8.7점)을 볼때 학생들의 성취도 차이가 작은 것을 알 수 있다.
# 평균성적보다 중위 성적이 낮으므로 평균 성적 이하의 학생들에게 보충수업이나, 수업자료를 더 주는 방향으로 성적변동성을 더 줄일 수 있다.

# %% [markdown]
# Q. 어느 도시에 지난 1년간 매달 내린 강수량 데이터는 다음과 같습니다:
#
# [85, 90, 78, 110, 88, 76, 120, 89, 77, 91, 100, 95].
#
# 이 데이터를 이용해 중간값과 1사분위수, 3사분위수를 계산하여 강수량의 분포를 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
rain = [85, 90, 78, 110, 88, 76, 120, 89, 77, 91, 100, 95]
df = pd.DataFrame(rain)
df.describe()
# Out:
#                 0
# count   12.000000
# mean    91.583333
# std     13.262787
# min     76.000000
# 25%     83.250000
# 50%     89.500000
# 75%     96.250000
# max    120.000000

# %%
df.index = range(1, 13)

# %%
plt.figure(figsize=(10, 6))
df.plot(kind='bar', legend=False)
plt.xlabel('Month',rotation=0)
plt.xticks(rotation=0)
plt.ylabel('Rainfall')
plt.title('Monthly Rainfall')
plt.show()

# %%
Q1 = df.iloc[0:3].mean()
Q2 = df.iloc[3:6].mean()
Q3 = df.iloc[6:9].mean()
Q4 = df.iloc[9:12].mean()

print(Q1,'\n', Q2,'\n', Q3,'\n', Q4)
# Out:
# 0    84.333333
# dtype: float64
#  0    91.333333
# dtype: float64
#  0    95.333333
# dtype: float64
#  0    95.333333
# dtype: float64

# %%
# 분기별 강수량의 평균들과 1년 강수량의 평균(91.5)과 1사분위(83.25), 중간값(89.5), 3사분위(96.25)를 비교했을때
# 이 지역은 1년동안 평균적으로 비가 고르게 내리고 있다는 것을 알 수 있다.

# %% [markdown]
# Q. 한 온라인 쇼핑몰의 지난 10일간 일일 방문자 수는 다음과 같습니다:
#
# [150, 200, 220, 180, 190, 170, 210, 230, 160, 175].
#
# 방문자 수의 분포를 시각화하기 위해 히스토그램을 그리고, 방문자 수의 변동성에 대한 인사이트를 도출하세요.

# %%
visitors = [150, 200, 220, 180, 190, 170, 210, 230, 160, 175]

df = pd.DataFrame(visitors, columns=["Visitors"])

# %%
df.describe()
# Out:
#             Day    Visitors
# count  10.00000   10.000000
# mean    5.50000  188.500000
# std     3.02765   26.251984
# min     1.00000  150.000000
# 25%     3.25000  171.250000
# 50%     5.50000  185.000000
# 75%     7.75000  207.500000
# max    10.00000  230.000000

# %%
# 히스토그램 그리기
plt.figure(figsize=(10, 6))
n, bins, patches = plt.hist(df["Visitors"], bins=5, color='skyblue', edgecolor='black')
plt.xlabel("Number of Visitors")
plt.ylabel("Frequency")
plt.title("Distribution of Daily Visitors to Online Shopping Malls (Last 10 Days)")
plt.grid(True)
plt.xticks(range(150, 241, 10))
plt.show()

# %%
# bin과 bin에 속하는 데이터의 개수 출력
for count, edge in zip(n, bins):
    print(f"Bin range: {edge:.1f} - {edge + (bins[1] - bins[0]):.1f}, Count: {count}")
# Out:
# Bin range: 150.0 - 166.0, Count: 2.0
# Bin range: 166.0 - 182.0, Count: 3.0
# Bin range: 182.0 - 198.0, Count: 1.0
# Bin range: 198.0 - 214.0, Count: 2.0
# Bin range: 214.0 - 230.0, Count: 2.0

# %%
visitors = [150, 200, 220, 180, 190, 170, 210, 230, 160, 175]
days = list(range(1, 11))

df = pd.DataFrame({'Day': days, 'Visitors': visitors})

# %%
# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
plt.bar(df['Day'], df['Visitors'], color='skyblue', edgecolor='black')
plt.xlabel('Day')
plt.ylabel('Number of Visitors')
plt.title('Daily Visitors to Online Shopping Malls (Last 10 Days)')
plt.xticks(df['Day'])
plt.grid(True)
plt.show()

# %%
# 일 평균 방문자 수는 188.5명이다.
# 하루에 못해도 150명의 방문자가 방문했다.
# 제일 많이 방문했을때는 230명이다.
# 이 온라인 쇼핑몰 방문자의 표준편차를 볼때 이 쇼핑몰은 안정적인 방문자 수를 가지고 있다.
# 방문자가 많은날 쿠폰이벤트 등으로 다시 재 방문하게 하여 방문자 수를 늘리는 방법이 좋을 것 같다.

# %% [markdown]
# Q. 한 회사의 직원 연봉 데이터가 다음과 같습니다:
#
# [45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000].
#
# 이 데이터를 이용하여 연봉의 분포와 이상치를 시각화하는 상자 그림을 그리고, 연봉 분포에 대한 인사이트를 도출하세요.

# %%
salaries = [45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000]
df = pd.DataFrame(pay)
df.describe()
# Out:
#                   0
# count     10.000000
# mean   53000.000000
# std     5715.476066
# min    45000.000000
# 25%    48500.000000
# 50%    52500.000000
# 75%    57250.000000
# max    62000.000000

# %%
# 직원 연봉 데이터
salaries = [45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000]

# 상자 그림 그리기
plt.figure(figsize=(8, 6))
sns.boxplot(y=salaries)
plt.title('Boxplot of Employee Salaries')
plt.xlabel('Salaries')
plt.show()

# %%
# 특정연봉(60000,62000)을 제외하고는 특별한 이상치가 없고, 중앙에 잘 분포되어있다는 것을 알 수 있다.
# 중간에 분포해 있는 연봉이 많으므로 성과급 지급으로 인해서 다른사람의 연봉을 쉽게 뒤집을 수도 있는 분위기가 형성되어있다면,
# 성과급 지급기준을 명확하게 정하고, 자기개발에 따른 보너스를 지급하는 기준을 만들어 직원들의 업무 사기 상승등을 노려볼 수 있다.

# %% [markdown]
# Q. 한 마케팅 캠페인에서 투자한 광고비와 발생한 매출 데이터가 각각 다음과 같습니다:
#
# 광고비 [1, 2, 3, 4, 5] (단위: 천 달러),
#
# 매출 [10, 15, 20, 25, 30] (단위: 천 달러).
#
# 광고비와 매출 간의 관계를 시각화하기 위해 산점도를 그리고, 두 변수 간의 관계에 대한 인사이트를 도출하세요.

# %%
# 천달러
ad_costs = [1, 2, 3, 4, 5]
revenues = [10, 15, 20, 25, 30]
df = pd.DataFrame(adv)
df.describe()
# Out:
#               0
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
# 산점도 그리기
plt.figure(figsize=(8, 6))
plt.scatter(ad_costs, revenues, color='blue')
plt.title('Scatter Plot of Advertising Costs and Revenues')
plt.xlabel('Advertising Costs (thousands of dollars)')
plt.ylabel('Revenues (thousands of dollars)')
plt.grid(True)
plt.show()

# %% [markdown]
# Q. 한 식당의 월별 홍보 비용과 월별 방문자 수 데이터가 각각 다음과 같습니다:
#
# 홍보 비용 [500, 600, 700, 800, 900] (단위: 달러),
#
# 방문자 수 [300, 400, 500, 600, 700] (단위: 명).
#
# 홍보 비용과 방문자 수 간의 상관 계수를 계산하여 관계를 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
adv_cost = [500, 600, 700, 800, 900]
visit = [300, 400, 500, 600, 700]
df = pd.DataFrame(adv_cost)
df.describe()
# Out:
#                 0
# count    5.000000
# mean   700.000000
# std    158.113883
# min    500.000000
# 25%    600.000000
# 50%    700.000000
# 75%    800.000000
# max    900.000000

# %% [markdown]
# Q. 세 종류의 화합물에 대한 실험 데이터를 다음 매트릭스로 나타냅니다:
#
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]].
#
# 이 매트릭스의 히트맵을 그려 데이터 간의 관계를 시각화하고, 인사이트를 도출하세요.

# %%
experiment = [[1, 2, 3], [2, 4, 6], [3, 6, 9]]
df = pd.DataFrame(experiment)
df.describe()
# Out:
#          0    1    2
# count  3.0  3.0  3.0
# mean   2.0  4.0  6.0
# std    1.0  2.0  3.0
# min    1.0  2.0  3.0
# 25%    1.5  3.0  4.5
# 50%    2.0  4.0  6.0
# 75%    2.5  5.0  7.5
# max    3.0  6.0  9.0

# %% [markdown]
# Q. 한 지역의 주택 가격 데이터가 다음과 같습니다:
#
# [250000, 300000, 350000, 400000, 450000, 500000, 550000, 600000, 650000, 700000].
#
# 주택 가격의 분포를 시각화하기 위해 분포 그래프를 그리고, 주택 가격 분포에 대한 인사이트를 도출하세요.

# %%
house_price = [250000, 300000, 350000, 400000, 450000, 500000, 550000, 600000, 650000, 700000]
df = pd.DataFrame(house_price)
df.describe()
# Out:
#                    0
# count      10.000000
# mean   475000.000000
# std    151382.517705
# min    250000.000000
# 25%    362500.000000
# 50%    475000.000000
# 75%    587500.000000
# max    700000.000000

# %% [markdown]
# Q. 한 교육기관의 시험 점수 데이터가 다음과 같습니다:
#
# [55, 60, 65, 70, 75, 80, 85, 90, 95, 100].
#
# 시험 점수의 도수 분포표를 작성하고, 이를 통해 성적 분포에 대한 인사이트를 도출하세요.

# %%
education = [55, 60, 65, 70, 75, 80, 85, 90, 95, 100]
df = pd.DataFrame(education)
df.describe()
# Out:
#                 0
# count   10.000000
# mean    77.500000
# std     15.138252
# min     55.000000
# 25%     66.250000
# 50%     77.500000
# 75%     88.750000
# max    100.000000

# %% [markdown]
# Q. 한 회사의 연구개발(R&D) 투자 비용과 연간 수익 데이터가 각각 다음과 같습니다:
#
# 투자 비용 [100, 200, 300, 400, 500] (단위: 천 달러),
#
# 연간 수익 [200, 400, 600, 800, 1000] (단위: 천 달러).
#
# 추세선이 있는 산점도를 그려 투자 비용과 연간 수익 간의 관계를 시각화하고, 인사이트를 도출하세요.

# %%
investment_cost = [100, 200, 300, 400, 500]
profit = [200, 400, 600, 800, 1000]
df = pd.DataFrame(investment_cost)
df.describe()
# Out:
#                 0
# count    5.000000
# mean   300.000000
# std    158.113883
# min    100.000000
# 25%    200.000000
# 50%    300.000000
# 75%    400.000000
# max    500.000000
