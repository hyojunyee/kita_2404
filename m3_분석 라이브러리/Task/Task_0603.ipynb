# %% [markdown]
# <a href="https://colab.research.google.com/github/hyojunyee/kita_2404/blob/main/m3_%EB%B6%84%EC%84%9D%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC/Task/Task_0603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# 데이터 불러오기
file_path = '/content/drive/MyDrive/kdt_240424/m3_분석라이브러리/m_3_datas/stock-data.csv'
# file_path = 'stock-data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Task1. 주어진 df의 날짜 리스트를 datetime 형식으로 변환하고, 변환된 데이터프레임의 년도, 월, 일 열을 추가하시오.

# %%
import pandas as pd

# 날짜 문자열 리스트
date_list = ['2023-01-01', '2023-02-15', '2023-03-30']

# 데이터프레임 생성
df = pd.DataFrame(date_list, columns=['date'])
# df = pd.Datati(date_list, columns=['date'])
# df['date_list'] = pd.to_datetime(df['date'])
# df.set_index('date', inplace=True)
df
# Out:
#          date
# 0  2023-01-01
# 1  2023-02-15
# 2  2023-03-30

# %%
# df.drop('date', axis=1, inplace=True)
# 연도, 월, 일 열 추가
df['연'] = df['date'].dt.year
df['월'] = df['date'].dt.month
df['일'] = df['date'].dt.day

# 결과 출력
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-383f46550b81> in <cell line: 3>()
#       1 # df.drop('date', axis=1, inplace=True)
#       2 # 연도, 월, 일 열 추가
# ----> 3 df['연'] = df['date'].dt.year
#       4 df['월'] = df['date'].dt.month
#       5 df['일'] = df['date'].dt.day
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# Task2. 주어진 월간 데이터를 타임스탬프로 변환하고, 변환된 결과에서 시간을 제외한 날짜만 출력하시오.

# %%
import pandas as pd

# 문자열을 Period로 변환
period_data = pd.Series(['2023-01', '2023-02', '2023-03'], name='period')
df = pd.DataFrame(period_data)
df
# Out:
#     period
# 0  2023-01
# 1  2023-02
# 2  2023-03

# %%
df['timestamp'] = pd.to_datetime(df['period'], format="%Y-%m")
df['date'] = df['timestamp'].dt.date
df = df.drop('period', axis=1)
df = df.drop('timestamp', axis=1)
print(df)
# Out:
#          date
# 0  2023-01-01
# 1  2023-02-01
# 2  2023-03-01

# %%
# 문자열을 Period로 변환
period_data = period_data.astype('period[M]')

# Period를 Timestamp로 변환
timestamp_data = period_data.apply(lambda x: x.to_timestamp())

# 날짜만 출력
# print(timestamp_data.date)
print(timestamp_data)
# Out:
# 0   2023-01-01
# 1   2023-02-01
# 2   2023-03-01
# Name: period, dtype: datetime64[ns]

# %% [markdown]
# Task3. 주어진 날짜 데이터 시리즈를 분기로 변환하고, 각 분기별로 데이터의 개수를 출력하세요.

# %%
# 날짜 데이터 시리즈
date_series = pd.Series(pd.date_range('2023-01-01', '2023-12-31', freq='M'))
date_series
# Out:
# 0    2023-01-31
# 1    2023-02-28
# 2    2023-03-31
# 3    2023-04-30
# 4    2023-05-31
# 5    2023-06-30
# 6    2023-07-31
# 7    2023-08-31
# 8    2023-09-30
# 9    2023-10-31
# 10   2023-11-30
# 11   2023-12-31
# dtype: datetime64[ns]

# %%
# 데이터프레임 생성
df = pd.DataFrame({'date': date_series})
df['value'] = 1  # 각 날짜에 대해 1의 값을 할당

# 날짜를 분기로 변환
df['quarter'] = df['date'].dt.to_period('Q')

# 각 분기별로 데이터의 개수를 계산
quarterly_count = df.groupby('quarter').size()

# 결과 출력
print(quarterly_count)
# Out:
# quarter
# 2023Q1    3
# 2023Q2    3
# 2023Q3    3
# 2023Q4    3
# Freq: Q-DEC, dtype: int64

# %%
# 날짜 데이터 시리즈
date_series = pd.Series(pd.date_range('2023-01-01', '2023-12-31', freq='M'))
date_series

# 날짜 데이터를 분기로 변환
quarter_data = date_series.dt.to_period('Q')

# 각 분기별 데이터 개수 세기
quarter_counts = quarter_data.value_counts().sort_index()

print(quarter_counts)
# Out:
# 2023Q1    3
# 2023Q2    3
# 2023Q3    3
# 2023Q4    3
# Freq: Q-DEC, Name: count, dtype: int64
