# %% [markdown]
# Task1_0813. 특정 주제에 대하여 다양한 프롬프트를 활용하여 원하는 결과를 출력할 수 있도록 수행하세요.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00

# %%
from openai import OpenAI

client = OpenAI(api_key="")

system = """
    ###당신은 한국의 근로기준법을 잘 알고 있는 근로기준법 관련 전문가 입니다.###
"""

user = """
2024년, 2025년 최저임금에 대해서 알려주세요
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
)

print(response.choices[0].message.content)
# Out:
# 2024년 최저임금은 2023년 7월 4일에 발표된 제정된 것으로, 시간당  10,600원입니다. 이는 2023년 최저임금인 9,620원에서 약 10.2% 인상된 금액입니다. 최저임금은 매년 인상 여부와 인상률을 결정하는데, 이는 고용노동부의 최저임금위원회에서 논의하게 됩니다.
#
# 최저임금은 근로자 보호를 위한 중요한 법적 기준으로, 최저임금 이하로 임금을 지급할 경우 법적 제재를 받을 수 있습니다. 다만, 최저임금을 적용받지 않는 경우(특정 소규모 사업장 등)도 있으니, 경우에 따라 다를 수 있습니다.
#
# 더 정확한 정보나 구체적인 사항이 필요하시면 고용노동부의 공식 웹사이트나 관련 기관의 근로기준법 자료를 참고하시기 바랍니다.

# %%
from openai import OpenAI

system = """
    ###당신은 한국의 근로기준법을 잘 알고 있는 근로기준법 관련 전문가 입니다.###
    ```- 당신의 역할은 근로기준법을 모르는 사람에게 관련 법에 관한 제도들을 설명해주는 것입니다.
    - 답변이 정확하지 않을 가능성이 높을 경우 잘 모른다고 답변해야 됩니다. 부정확한 답변은 하지 않는게 좋습니다.
    - 질문이 구체적이라면 그 방법도 구체적으로 알려주는것이 좋습니다.
    - 또한 유저에게 중요해 보이는 부분에 대해서 다시 질문해서 대응을 도와주는 것도 중요합니다.
    - 답변에 대해서는 최대한 상세하게 알려주세요
    - 금액 산정에 관한 질문에는 돈의 성격에 따라서 세금이나, 수당, 공제 등 여러가지 변수들이 있을 수 있음으로 성격에 맞게 이를 명시하여 주세요```

```
    - 2024년 최저임금은 9,860원 입니다.
    - 2025년 최저임금은 10,030원 입니다.
```
"""

user = """
2024년, 2025년 최저임금에 대해서 설명해주세요.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.7,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# 최저임금에 대해서는 2024년과 2025년의 구체적인 금액이 아직 정해지지 않았습니다. 보통 최저임금은 매년 개정되며, 한국에서는 매년 7월에 최저임금위원회가 다음 연도의 최저임금을 결정합니다. 이를 바탕으로 2024년과 2025년의 최저임금이 발표될 것입니다.
#
# 최저임금은 매년 물가 인상, 경제 상황, 노동자의 생활 수준 등을 고려하여 조정되므로, 이와 관련한 논의는 한국의 노동 시장과 경제 상황에 따라 다를 수 있습니다.
#
# 최저임금 관련하여 더 구체적인 정보나 궁금한 점이 있으신가요? 예를 들어 최저임금을 받을 수 있는 근로자의 조건이나, 최저임금이 적용되는 근로 형태에 대해 알고 싶으신 부분이 있다면 말씀해 주세요.

# %%
    # - 2024년 최저임금은 9,860원 입니다.
    # - 2025년 최저임금은 10,030원 입니다.

# %% [markdown]
# Task2_0813. Temperature 와 Top-P의 조합으로 4가지 사례를 작성하고 결과에 대해 의미를 확인하세요.

# %% [markdown]
# **높은 Temperature (1.0 이상) + 높은 Top-p (0.9~1.0)**

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=1,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 물의 아름다움을 표현하는 데 있어 파란색은 정말 멋진 선택이에요! 다양한 밝기의 파란색을 사용하면 깊이감과 움직임을 더할 수 있습니다. 다음 질문들을 생각해 보세요:
#
# 1. **물의 움직임**: 바다의 파도나 강의 흐름을 표현하고 싶으신가요? 그렇다면 물결이나 물방울의 형태를 어떻게 나타내고 싶으신가요?
#
# 2. **자연의 요소**: 물과 함께 어떤 다른 자연 요소를 추가하고 싶으신가요? 예를 들어, 해양 생물이나 주변의 식물, 하늘의 색 등은 어떤가요?
#
# 3. **감정이나 분위기**: 이 그림을 통해 어떤 감정이나 분위기를 전달하고 싶으신가요? 차분함, 역동성, 혹은 신비로움 같은 느낌을 담고 싶으신가요?
#
# 4. **구성**: 그림의 구도는 어떻게 설정할까요? 물이 주인공인지, 아니면 물 위에 있는 다른 요소들이 강조되는 형태인지 고민해 보세요.
#
# 이 질문들이 당신의 작품에 대한 아이디어를 발전시키는 데 도움이 될 수 있기를 바랍니다!

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=1,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 아름다운 주제입니다! 바다나 강의 물을 표현할 때 여러 가지 밝기의 파란색을 사용하는 것은 정말 효과적일 거예요. 당신의 작품에 대한 더 깊은 영감을 주기 위해 몇 가지 질문을 드릴게요.
#
# 1. **물의 감정**: 당신이 표현하고 싶은 물의 감정이나 분위기가 있나요? 예를 들어, 잔잔하고 평화로운 바다, 혹은 거칠고 격렬한 파도처럼요.
#
# 2. **물과 자연의 상호작용**: 물이 다른 자연 요소들과 어떻게 상호작용하는 장면을 그려보고 싶나요? 예를 들어, 물속의 생물, 해변의 모래, 혹은 나무의 반사 등.
#
# 3. **빛의 변화**: 당신은 어떤 빛의 변화나 시간대에서 영감을 받을 수 있을까요? 예를 들어, 일출, 한낮, 석양 등 다양한 시간대의 물빛을 그려볼 수 있습니다.
#
# 4. **추가 요소**: 물 외에 추가하고 싶은 요소가 있을까요? 예를 들어, 보트, 물고기, 혹은 사람의 모습 같은 것들이요.
#
# 이 질문들이 당신의 창작에 도움이 되었으면 좋겠어요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 물의 아름다움을 표현하는 데 있어 파란색은 정말 멋진 선택이에요! 다양한 밝기의 파란색을 사용하면 깊이감과 움직임을 더할 수 있습니다. 다음 질문들을 생각해 보세요:
#
# 1. **물의 움직임**: 바다의 파도나 강의 흐름을 표현하고 싶으신가요? 그렇다면 물결이나 물방울의 형태를 어떻게 나타내고 싶으신가요?
#
# 2. **자연의 요소**: 물과 함께 어떤 다른 자연 요소를 추가하고 싶으신가요? 예를 들어, 해양 생물이나 주변의 식물, 하늘의 색 등은 어떤가요?
#
# 3. **감정이나 분위기**: 이 그림을 통해 어떤 감정이나 분위기를 전달하고 싶으신가요? 차분함, 역동성, 혹은 신비로움 같은 느낌을 담고 싶으신가요?
#
# 4. **구성**: 그림의 구도는 어떻게 설정할까요? 물이 주인공인지, 아니면 물 위에 있는 다른 요소들이 강조되는 형태인지 고민해 보세요.
#
# 이 질문들이 당신의 작품에 대한 아이디어를 발전시키는 데 도움이 될 수 있기를 바랍니다!

# %% [markdown]
# 아름다운 주제입니다! 바다나 강의 물을 표현할 때 여러 가지 밝기의 파란색을 사용하는 것은 정말 효과적일 거예요. 당신의 작품에 대한 더 깊은 영감을 주기 위해 몇 가지 질문을 드릴게요.
#
# 1. **물의 감정**: 당신이 표현하고 싶은 물의 감정이나 분위기가 있나요? 예를 들어, 잔잔하고 평화로운 바다, 혹은 거칠고 격렬한 파도처럼요.
#
# 2. **물과 자연의 상호작용**: 물이 다른 자연 요소들과 어떻게 상호작용하는 장면을 그려보고 싶나요? 예를 들어, 물속의 생물, 해변의 모래, 혹은 나무의 반사 등.
#
# 3. **빛의 변화**: 당신은 어떤 빛의 변화나 시간대에서 영감을 받을 수 있을까요? 예를 들어, 일출, 한낮, 석양 등 다양한 시간대의 물빛을 그려볼 수 있습니다.
#
# 4. **추가 요소**: 물 외에 추가하고 싶은 요소가 있을까요? 예를 들어, 보트, 물고기, 혹은 사람의 모습 같은 것들이요.
#
# 이 질문들이 당신의 창작에 도움이 되었으면 좋겠어요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# **높은 Temperature (1.0 이상) + 낮은 Top-p (0.3~0.7)**

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=1,
    top_p=0.5
)

print(response.choices[0].message.content)
# Out:
# 물과 자연을 주제로 한 그림을 그리려는 아이디어가 정말 멋지네요! 파란색의 다양한 밝기를 활용하면 깊이감과 생동감을 줄 수 있을 거예요. 몇 가지 질문을 통해 더 구체적인 영감을 드릴게요.
#
# 1. **물의 상태**: 바다, 강, 호수 중 어떤 물을 그릴 생각인가요? 각각의 물은 다른 느낌과 분위기를 줄 수 있어요.
#
# 2. **시간대**: 그림의 배경이 낮인지, 저녁인지, 아니면 밤인지 고민해보셨나요? 시간대에 따라 색의 톤과 분위기가 달라질 수 있어요.
#
# 3. **구성 요소**: 물 외에 어떤 다른 요소를 추가하고 싶으신가요? 예를 들어, 물속의 생물이나 주변의 식물, 하늘의 구름 등도 함께 그리면 좋을 것 같아요.
#
# 4. **감정이나 메시지**: 이 그림을 통해 어떤 감정이나 메시지를 전달하고 싶으신가요? 그에 따라 색상과 구도를 조정할 수 있을 거예요.
#
# 이 질문들을 통해 더 구체적인 아이디어를 떠올릴 수 있을 것 같아요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# **낮은 Temperature (0.2\~0.5) + 높은 Top-p (0.9~1.0)**

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.2,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 멋진 아이디어네요! 물의 다양한 색조와 밝기를 활용하면 깊이감과 생동감을 줄 수 있을 거예요. 몇 가지 질문을 통해 더 구체적인 영감을 드릴게요.
#
# 1. **물의 상태**: 바다와 강 중 어떤 느낌을 더 강조하고 싶으신가요? 잔잔한 물결, 파도가 치는 바다, 혹은 흐르는 강의 느낌?
#
# 2. **감정 표현**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동적인 에너지?
#
# 3. **구성 요소**: 물 외에 어떤 다른 요소를 추가하고 싶으신가요? 예를 들어, 물속의 생물, 해변의 모래, 나무, 혹은 하늘의 구름 등.
#
# 4. **기법**: 어떤 기법을 사용하고 싶으신가요? 수채화처럼 부드러운 느낌, 아크릴로 강렬한 색감을 표현, 혹은 유화로 깊이 있는 질감을 주는 방법 등.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 거예요! 어떤 방향으로 나아가고 싶으신가요?

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.2,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회를 제공합니다. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같아요.
#
# 몇 가지 질문을 통해 더 깊이 있는 영감을 드릴게요:
#
# 1. **물의 상태**: 바다나 강의 어떤 상태를 표현하고 싶으신가요? 잔잔한 물결, 폭풍우가 치는 바다, 혹은 맑고 투명한 강물 등 다양한 느낌이 있을 수 있어요.
#
# 2. **시간대**: 어떤 시간대의 풍경을 그릴 계획이신가요? 아침의 부드러운 빛, 정오의 강렬한 햇빛, 저녁의 따뜻한 색조 등 시간에 따라 물의 색감이 달라질 수 있어요.
#
# 3. **주변 환경**: 물가 주변의 풍경은 어떤 모습일까요? 해변의 모래사장, 강가의 나무들, 혹은 도시의 스카이라인 등 다양한 요소가 그림에 추가될 수 있습니다.
#
# 4. **감정 표현**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동적인 에너지를 표현하고 싶으신가요?
#
# 이 질문들을 통해 더 구체적인 아이디어가 떠오를 수 있을 거예요. 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 멋진 아이디어네요! 물의 다양한 색조와 밝기를 활용하면 깊이감과 생동감을 줄 수 있을 거예요. 몇 가지 질문을 통해 더 구체적인 영감을 드릴게요.
#
# 1. **물의 상태**: 바다와 강 중 어떤 느낌을 더 강조하고 싶으신가요? 잔잔한 물결, 파도가 치는 바다, 혹은 흐르는 강의 느낌?
#
# 2. **감정 표현**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동적인 에너지?
#
# 3. **구성 요소**: 물 외에 어떤 다른 요소를 추가하고 싶으신가요? 예를 들어, 물속의 생물, 해변의 모래, 나무, 혹은 하늘의 구름 등.
#
# 4. **기법**: 어떤 기법을 사용하고 싶으신가요? 수채화처럼 부드러운 느낌, 아크릴로 강렬한 색감을 표현, 혹은 유화로 깊이 있는 질감을 주는 방법 등.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 거예요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회를 제공합니다. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같아요.
#
# 몇 가지 질문을 통해 더 깊이 있는 영감을 드릴게요:
#
# 1. **물의 상태**: 바다나 강의 어떤 상태를 표현하고 싶으신가요? 잔잔한 물결, 폭풍우가 치는 바다, 혹은 맑고 투명한 강물 등 다양한 느낌이 있을 수 있어요.
#
# 2. **시간대**: 어떤 시간대의 풍경을 그릴 계획이신가요? 아침의 부드러운 빛, 정오의 강렬한 햇빛, 저녁의 따뜻한 색조 등 시간에 따라 물의 색감이 달라질 수 있어요.
#
# 3. **주변 환경**: 물가 주변의 풍경은 어떤 모습일까요? 해변의 모래사장, 강가의 나무들, 혹은 도시의 스카이라인 등 다양한 요소가 그림에 추가될 수 있습니다.
#
# 4. **감정 표현**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동적인 에너지를 표현하고 싶으신가요?
#
# 이 질문들을 통해 더 구체적인 아이디어가 떠오를 수 있을 거예요. 어떤 방향으로 나아가고 싶으신가요?

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.2,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 많은 감정을 담을 수 있을 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 표현할 수 있겠죠.
#
# 여기 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다나 강의 어떤 상태를 표현하고 싶으신가요? 잔잔한 물결, 거센 파도, 혹은 흐르는 강물의 모습 등 어떤 느낌을 원하시나요?
#
# 2. **시간대**: 어떤 시간대를 표현하고 싶으신가요? 아침의 부드러운 빛, 정오의 강렬한 햇빛, 저녁의 따뜻한 색감 등 각기 다른 분위기를 줄 수 있습니다.
#
# 3. **주변 요소**: 물 외에 어떤 요소를 추가하고 싶으신가요? 예를 들어, 해양 생물, 나무, 바위, 혹은 사람의 모습 등 다양한 요소가 그림에 생명을 불어넣을 수 있습니다.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 거예요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 멋진 아이디어네요! 물의 다양한 색조와 밝기를 활용하면 깊이감과 생동감을 줄 수 있을 거예요. 몇 가지 질문을 통해 더 구체적인 영감을 드릴게요.
#
# 1. **물의 상태**: 바다와 강 중 어떤 느낌을 더 강조하고 싶으신가요? 잔잔한 물결, 파도가 치는 바다, 혹은 흐르는 강의 느낌?
#
# 2. **감정 표현**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동적인 에너지?
#
# 3. **구성 요소**: 물 외에 어떤 다른 요소를 추가하고 싶으신가요? 예를 들어, 물속의 생물, 해변의 모래, 나무, 혹은 하늘의 구름 등.
#
# 4. **기법**: 어떤 기법을 사용하고 싶으신가요? 수채화처럼 부드러운 느낌, 아크릴로 강렬한 색감을 표현, 혹은 유화로 깊이 있는 질감을 주는 방법 등.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 거예요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 많은 감정을 담을 수 있을 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 표현할 수 있겠죠.
#
# 여기 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다나 강의 어떤 상태를 표현하고 싶으신가요? 잔잔한 물결, 거센 파도, 혹은 흐르는 강물의 모습 등 어떤 느낌을 원하시나요?
#
# 2. **시간대**: 어떤 시간대를 표현하고 싶으신가요? 아침의 부드러운 빛, 정오의 강렬한 햇빛, 저녁의 따뜻한 색감 등 각기 다른 분위기를 줄 수 있습니다.
#
# 3. **주변 요소**: 물 외에 어떤 요소를 추가하고 싶으신가요? 예를 들어, 해양 생물, 나무, 바위, 혹은 사람의 모습 등 다양한 요소가 그림에 생명을 불어넣을 수 있습니다.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 거예요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# **낮은 Temperature (0.2\~0.5) + 낮은 Top-p (0.3~0.7)**

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.1,
    top_p=0.3
)

print(response.choices[0].message.content)
# Out:
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회가 될 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같습니다.
#
# 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다의 잔잔한 모습, 파도가 이는 모습, 혹은 강의 흐름 등 어떤 상태의 물을 그리고 싶으신가요?
#
# 2. **시간대**: 아침의 부드러운 빛, 정오의 강렬한 햇빛, 혹은 저녁의 따뜻한 색감 중 어떤 시간대를 표현하고 싶으신가요?
#
# 3. **감정**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동성 같은 느낌이 있을까요?
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 것 같아요!

# %%
from openai import OpenAI

system = """
    ###너의 역할은 예술 분야의 영감을 주는 도우미야###
```
    - 너의 역할은 새로운 작품을 고민하는 사람들한테 영감을 주는 것
    - 유저에게 영감을 줄 수 있는 부분에 대해서 다시 질문해서 인사이트를 주는 것도 중요
```
"""

user = """
새로운 그림을 그릴건데 바다나 강과같은 물이 자연이 되었으면 좋겠어
파란색을 쓸건데 여러가지 밝기의 색을 쓸 수 있으면 좋겠어
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
        "role": "system",
        "content": system
        },
        {"role": "user",
         "content": user
        }
    ],
    temperature=0.1,
    top_p=0.3
)

print(response.choices[0].message.content)
# Out:
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회가 될 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같습니다.
#
# 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다의 잔잔한 모습, 혹은 강의 빠른 흐름 중 어떤 느낌을 원하시나요? 물의 상태에 따라 색감과 표현이 달라질 수 있어요.
#
# 2. **시간대**: 아침의 맑은 하늘, 저녁의 노을, 혹은 밤의 고요한 물가 중 어떤 시간대를 표현하고 싶으신가요? 시간대에 따라 색의 조화가 달라질 수 있습니다.
#
# 3. **주변 환경**: 물가 주변에 어떤 요소를 추가하고 싶으신가요? 예를 들어, 나무, 바위, 혹은 사람의 실루엣 등 다양한 요소가 그림에 생동감을 줄 수 있습니다.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 것 같아요! 어떤 방향으로 나아가고 싶으신가요?

# %% [markdown]
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회가 될 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같습니다.
#
# 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다의 잔잔한 모습, 파도가 이는 모습, 혹은 강의 흐름 등 어떤 상태의 물을 그리고 싶으신가요?
#
# 2. **시간대**: 아침의 부드러운 빛, 정오의 강렬한 햇빛, 혹은 저녁의 따뜻한 색감 중 어떤 시간대를 표현하고 싶으신가요?
#
# 3. **감정**: 이 그림을 통해 어떤 감정을 전달하고 싶으신가요? 평화로움, 신비로움, 혹은 역동성 같은 느낌이 있을까요?
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 것 같아요!

# %% [markdown]
# 멋진 아이디어네요! 바다나 강을 주제로 한 그림은 정말 다양한 감정을 표현할 수 있는 기회가 될 것 같아요. 파란색의 다양한 밝기를 활용하면 깊이와 움직임을 잘 나타낼 수 있을 것 같습니다.
#
# 몇 가지 질문을 드려볼게요:
#
# 1. **물의 상태**: 바다의 잔잔한 모습, 혹은 강의 빠른 흐름 중 어떤 느낌을 원하시나요? 물의 상태에 따라 색감과 표현이 달라질 수 있어요.
#
# 2. **시간대**: 아침의 맑은 하늘, 저녁의 노을, 혹은 밤의 고요한 물가 중 어떤 시간대를 표현하고 싶으신가요? 시간대에 따라 색의 조화가 달라질 수 있습니다.
#
# 3. **주변 환경**: 물가 주변에 어떤 요소를 추가하고 싶으신가요? 예를 들어, 나무, 바위, 혹은 사람의 실루엣 등 다양한 요소가 그림에 생동감을 줄 수 있습니다.
#
# 이 질문들을 통해 더 구체적인 아이디어를 발전시킬 수 있을 것 같아요! 어떤 방향으로 나아가고 싶으신가요?
